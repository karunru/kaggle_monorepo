# %%
# !pip install /kaggle/input/CMI-Detect-Behavior-with-Sensor-Data-deps/*.whl --force-reinstall --root-user-action ignore --no-deps --no-index --find-links /kaggle/input/CMI-Detect-Behavior-with-Sensor-Data-deps

# %%
# !PYTHONPATH=/kaggle/input/cmi-codes/exp/exp007/ python /kaggle/input/cmi-codes/exp/exp007/inference.py
